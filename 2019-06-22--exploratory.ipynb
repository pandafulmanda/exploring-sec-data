# %%
import pandas
from xbrl import XBRLParser, GAAP, GAAPSerializer

# %%
all_submissions = pandas.read_csv('./sub.tsv', sep='\t')

# %%
all_submissions
# Out:
#                       adsh      cik  \
# 0     0000002178-19-000011     2178
# 1     0000002488-19-000011     2488
# 2     0000002969-19-000014     2969
# 3     0000003499-19-000004     3499
# 4     0000003545-19-000015     3545
# 5     0000003545-19-000026     3545
# 6     0000003570-19-000030     3570
# 7     0000004127-19-000013     4127
# 8     0000004281-19-000031     4281
# 9     0000004457-19-000005     4457
# 10    0000004904-19-000009     4904
# 11    0000004962-19-000018     4962
# 12    0000004969-19-000006     4969
# 13    0000004977-19-000049     4977
# 14    0000005272-19-000023     5272
# 15    0000005513-19-000004     5513
# 16    0000006201-19-000009     6201
# 17    0000006281-19-000013     6281
# 18    0000006845-19-000005     6845
# 19    0000006951-19-000008     6951
# 20    0000006955-19-000005     6955
# 21    0000007039-19-000030     7039
# 22    0000007084-19-000012     7084
# 23    0000007332-19-000010     7332
# 24    0000007789-19-000014     7789
# ...

# %%
netflix_filing = pandas.read_csv('./netflix-num.tsv', sep='\t')

# %%
netflix_filing
# Out:
#                       adsh                                                tag  \
# 0     0001065280-19-000043                            ContentAssetsNetCurrent
# 1     0001065280-19-000043                            ContentAssetsNetCurrent
# 2     0001065280-19-000043                          ContentLiabilitiesCurrent
# 3     0001065280-19-000043                          ContentLiabilitiesCurrent
# 4     0001065280-19-000043                          ContentLiabilitiesCurrent
# 5     0001065280-19-000043                          ContentLiabilitiesCurrent
# 6     0001065280-19-000043  CapitalandOperatingLeasesFutureMinimumPayments...
# 7     0001065280-19-000043  CapitalandOperatingLeasesFutureMinimumPayments...
# 8     0001065280-19-000043  AverageProducedContentAssetAmortizationPercentage
# 9     0001065280-19-000043          CostofServicesAmortizationofContentAssets
# 10    0001065280-19-000043          CostofServicesAmortizationofContentAssets
# ...

# %%
netflix_filing[netflix_filing.tag == 'ContentLiabilitiesCurrent']
# Out:
#                    adsh                        tag               version  \
# 2  0001065280-19-000043  ContentLiabilitiesCurrent  0001065280-19-000043
# 3  0001065280-19-000043  ContentLiabilitiesCurrent  0001065280-19-000043
# 4  0001065280-19-000043  ContentLiabilitiesCurrent  0001065280-19-000043
# 5  0001065280-19-000043  ContentLiabilitiesCurrent  0001065280-19-000043
#
#       ddate  qtrs  uom                                dimh  iprx  \
# 2  20171231     0  USD                          0x00000000     0
# 3  20171231     0  USD  0xdf82668a13a8aa461cf1cd08b54cea87     0
# 4  20181231     0  USD                          0x00000000     0
# 5  20181231     0  USD  0xdf82668a13a8aa461cf1cd08b54cea87     0
#
#           value  footnote  footlen  dimn  coreg  durp  datp  dcml
# 2  4.173041e+09       NaN        0     0    NaN   0.0   0.0    -3
# 3  4.200000e+09       NaN        0     1    NaN   0.0   0.0    -8
# 4  4.686019e+09       NaN        0     0    NaN   0.0   0.0    -3
# ...

# %%
list(netflix_filing.tag.unique())
# Out:
# ['ContentAssetsNetCurrent',
#  'ContentLiabilitiesCurrent',
#  'CapitalandOperatingLeasesFutureMinimumPaymentsDueinFourYears',
#  'CapitalandOperatingLeasesFutureMinimumPaymentsDueThereafter',
#  'AverageProducedContentAssetAmortizationPercentage',
#  'CostofServicesAmortizationofContentAssets',
#  'EffectiveIncomeTaxReconciliationChangeinTaxReserves',
#  'FiniteLivedIntangibleAssetsAmortizationinPeriodTrancheTwoPercent',
#  'LineofCreditFacilityAdditionalMaximumBorrowingCapacity',
#  'NumberOfPaidMembershipAdditionsDuringPeriod',
#  'TaxCutsAndJobsActIncomeTaxExpenseBenefit',
#  'TaxCutsAndJobsActOf2017IncompleteAccountingTransitionTaxForAccumulatedForeignEarningsProvisionalIncomeTaxExpenseBenefit',
#  'AdvertisingExpense',
#  'AssetsCurrent',
#  'CapitalLeaseObligations',
#  'CommitmentsAndContingencies',
#  'CommonStockCapitalSharesReservedForFutureIssuance',
#  'CurrentIncomeTaxExpenseBenefit',
#  'DeferredFinanceCostsNet',
#  'DeferredStateAndLocalIncomeTaxExpenseBenefit',
# ...

# %%
netflix_filing_notes = pandas.read_csv('./netflix-txt.tsv', sep='\t')

# %%
netflix_filing_notes
# Out:
#                     adsh                                                tag  \
# 0   0001065280-19-000043  ScheduleOfShareBasedPaymentAwardStockOptionsVa...
# 1   0001065280-19-000043       PropertyPlantAndEquipmentDisclosureTextBlock
# 2   0001065280-19-000043                              EntityCentralIndexKey
# 3   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 4   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 5   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 6   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 7   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 8   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 9   0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# 10  0001065280-19-000043                PropertyPlantAndEquipmentUsefulLife
# ...

# %%
netflix_filing[netflix_filing.tag == 'Revenues']
# Out:
#                       adsh       tag       version     ddate  qtrs  uom  \
# 1188  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1189  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1190  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1191  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1192  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1193  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1194  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1195  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1196  0001065280-19-000043  Revenues  us-gaap/2018  20160331     1  USD
# 1197  0001065280-19-000043  Revenues  us-gaap/2018  20160630     1  USD
# 1198  0001065280-19-000043  Revenues  us-gaap/2018  20160630     1  USD
# 1199  0001065280-19-000043  Revenues  us-gaap/2018  20160630     1  USD
# ...

# %%
xbrl_parser = XBRLParser()
xbrl = xbrl_parser.parse(open("nflx-20190331.xml"))

# %%
gaap_obj = xbrl_parser.parseGAAP(xbrl, doc_date="20190331", context="current", ignore_errors=0)

# %%
serializer = GAAPSerializer()
result = serializer.dump(gaap_obj)

# %%
result.data
# Out:
# {'net_cash_flows_operating_continuing': 0.0,
#  'redeemable_noncontrolling_interest': 0.0,
#  'assets': 27218632.0,
#  'income_tax_expense_benefit': 0.0,
#  'income_before_equity_investments': 0.0,
#  'net_cash_flows_operating': 0.0,
#  'operating_income_loss': 0.0,
#  'income_loss': 0.0,
#  'commitments_and_contingencies': 0.0,
#  'preferred_stock_dividends': 0.0,
#  'current_liabilities': 0.0,
#  'revenue': 0.0,
#  'other_operating_income': 0.0,
#  'equity_attributable_interest': 0.0,
#  'non_current_assets': 1726568.0,
#  'net_income_loss': 0.0,
#  'comprehensive_income_interest': 0.0,
#  'liabilities': 746268.0,
#  'net_income_parent': 0.0,
#  'net_income_shareholders': 0.0,
#  'income_from_equity_investments': 0.0,
#  'comprehensive_income': 0.0,
#  'common_shares_outstanding': 0.0,
#  'temporary_equity': 0.0,
#  'operating_expenses': 0.0,
#  'net_income_loss_noncontrolling': 0.0,
#  'cost_of_revenue': 0.0,
#  'costs_and_expenses': 0.0,
# ...
